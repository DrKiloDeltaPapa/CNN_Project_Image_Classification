# %%
import os

# Define the source folder for the Humans images
source_folder = "/home/locutus/Downloads/CNN_Project_Group_17/dataset/test/Humans"  # Path to the "Humans" folder

# List all files in the folder
images = os.listdir(source_folder)

# Sort the files in case the order matters (e.g., alphabetical)
images.sort()

# Rename the images with the "human_" prefix followed by the image number
for i, img in enumerate(images):
    # Ensure it's an image file (optional check, in case there are non-image files)
    if img.lower().endswith(('.png', '.jpg', '.jpeg')):
        # Get the file extension (e.g., .jpg, .png)
        extension = img.split('.')[-1]
        # Construct the new name (e.g., human_1.jpg, human_2.jpg)
        new_name = f"human_{i + 1}.{extension}"

        # Rename the image
        os.rename(os.path.join(source_folder, img), os.path.join(source_folder, new_name))

        print(f"Renamed: {img} -> {new_name}")

print("Renaming complete!")
# Out:
# Renamed: 00000015.jpg -> human_1.jpg
# Renamed: 00000061.jpg -> human_2.jpg
# Renamed: 00000075.jpg -> human_3.jpg
# Renamed: 00000088.jpg -> human_4.jpg
# Renamed: 000001.jpg -> human_5.jpg
# Renamed: 00000118.jpg -> human_6.jpg
# Renamed: 00000119.jpg -> human_7.jpg
# Renamed: 00000145.jpg -> human_8.jpg
# Renamed: 00000150.jpg -> human_9.jpg
# Renamed: 00000168.jpg -> human_10.jpg
# Renamed: 00000179.jpg -> human_11.jpg
# Renamed: 00000205.jpg -> human_12.jpg
# Renamed: 00000206.jpg -> human_13.jpg
# Renamed: 00000211.jpg -> human_14.jpg
# Renamed: 00000226.jpg -> human_15.jpg
# Renamed: 00000282.jpg -> human_16.jpg
# Renamed: 00000317.jpg -> human_17.jpg
# Renamed: 00000361.jpg -> human_18.jpg
# Renamed: 00000363.jpg -> human_19.jpg
# Renamed: 00000419.jpg -> human_20.jpg
# Renamed: 00000423.jpg -> human_21.jpg
# Renamed: 00000432.jpg -> human_22.jpg
# Renamed: 00000448.jpg -> human_23.jpg
# Renamed: 00000478.jpg -> human_24.jpg
# Renamed: 00000479.jpg -> human_25.jpg
# ...
